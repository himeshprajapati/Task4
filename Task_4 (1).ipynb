# %%
from google.colab.patches import cv2_imshow

# %% [markdown]
# # LGM VIP JAN 2023
#
# ### Name-Divya Singh
#
# ### Task-4: Image to Pencil Sketch with Python:

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in f:\anaconda3\lib\site-packages (4.5.3.56)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.17.3 in f:\anaconda3\lib\site-packages (from opencv-python) (1.19.2)

# %%
#import the library
import cv2

# %%
filename = 'virat.JPG'

# %%
#read the image
input_img = cv2.imread(filename)

# %%
#convert the image to gray scale
gray_image = cv2.cvtColor(input_img, cv2.COLOR_BGR2GRAY)

# %%
#invert the image
inverted_gray_image = 255 - gray_image

# %%
#blur the image by gaussian blur
blurred_image = cv2.GaussianBlur(inverted_gray_image, (21, 21), 0)

# %%
#invert the blurred image
inverted_blurred_image = 255 - blurred_image

# %%
#create the pencil sketch image
pencil_sketch_image = cv2.divide(gray_image, inverted_blurred_image, scale = 256.0)

# %%
#show the various images

cv2_imshow(input_img)
cv2_imshow(gray_image)
cv2_imshow(inverted_gray_image)
# Out:
# <PIL.Image.Image image mode=RGB size=700x1050 at 0x7F76F125EE50>
# <PIL.Image.Image image mode=L size=700x1050 at 0x7F76E0A3C9D0>
# <PIL.Image.Image image mode=L size=700x1050 at 0x7F76F125EE50>

# %%
cv2_imshow(pencil_sketch_image)
# Out:
# <PIL.Image.Image image mode=L size=700x1050 at 0x7F76E0ACE160>

# %%
cv2.waitKey(0)
# Out:
# -1
